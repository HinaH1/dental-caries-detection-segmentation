# %% [markdown]
# <a href="https://colab.research.google.com/github/HinaH1/dental-caries-detection-segmentation/blob/main/phase_two/results/experiment_two_additional_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Connect to google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Replace with your actual path
dataset_path = "/content/drive/MyDrive/Copy of SEGMENTATION"

for root, dirs, files in os.walk(dataset_path):
    level = root.replace(dataset_path, '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    if level < 2:
        subindent = ' ' * 2 * (level + 1)
        for file in files[:5]:
            print(f'{subindent}{file}')
# Out:
# Copy of SEGMENTATION/
#   SEGMENTATION/
#     images/
#     labels/

# %%
import os
import shutil

base = "/content/drive/MyDrive/Copy of SEGMENTATION/SEGMENTATION"
images_src = os.path.join(base, "images")
labels_src = os.path.join(base, "labels")

# Create new folder structure
for split in ['train', 'val', 'test']:
    os.makedirs(f"{base}/{split}/images", exist_ok=True)
    os.makedirs(f"{base}/{split}/labels", exist_ok=True)

# Move images
for f in os.listdir(images_src):
    if f.startswith('train_') or f.startswith('train2_'):
        shutil.copy(os.path.join(images_src, f), f"{base}/train/images/{f}")
    elif f.startswith('val_'):
        shutil.copy(os.path.join(images_src, f), f"{base}/val/images/{f}")
    elif f.startswith('test_'):
        shutil.copy(os.path.join(images_src, f), f"{base}/test/images/{f}")

# Move labels
for f in os.listdir(labels_src):
    if f.startswith('train_') or f.startswith('train2_'):
        shutil.copy(os.path.join(labels_src, f), f"{base}/train/labels/{f}")
    elif f.startswith('val_'):
        shutil.copy(os.path.join(labels_src, f), f"{base}/val/labels/{f}")
    elif f.startswith('test_'):
        shutil.copy(os.path.join(labels_src, f), f"{base}/test/labels/{f}")

print("Done reorganising files")
# Out:
# Done reorganising files

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.8 MB/s eta 0:00:00
# ...

# %%
model_path = "/content/drive/MyDrive/best_2.pt"

# %%
test_path = "/content/drive/MyDrive/Copy of SEGMENTATION/SEGMENTATION/test/images"

# %%
from ultralytics import YOLO

model = YOLO(model_path)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
results = model.predict(
    source =test_path,
    save=True,
    project = "/content/drive/MyDrive/exp2_results",
    name = "exp1",
    conf = 0.25
)
# Out:
# image 1/358 /content/drive/MyDrive/Copy of SEGMENTATION/SEGMENTATION/test/images/test_crawling_0.jpg: 640x640 1 caries, 9.2ms
# image 2/358 /content/drive/MyDrive/Copy of SEGMENTATION/SEGMENTATION/test/images/test_crawling_10.jpg: 640x640 1 caries, 11.1ms
# image 3/358 /content/drive/MyDrive/Copy of SEGMENTATION/SEGMENTATION/test/images/test_crawling_100.jpg: 640x640 1 caries, 9.2ms
# image 4/358 /content/drive/MyDrive/Copy of SEGMENTATION/SEGMENTATION/test/images/test_crawling_101.jpg: 640x640 2 cariess, 20.2ms
# image 5/358 /content/drive/MyDrive/Copy of SEGMENTATION/SEGMENTATION/test/images/test_crawling_102.jpg: 640x640 2 cariess, 10.0ms
# image 6/358 /content/drive/MyDrive/Copy of SEGMENTATION/SEGMENTATION/test/images/test_crawling_103.jpg: 640x640 2 cariess, 9.2ms
# image 7/358 /content/drive/MyDrive/Copy of SEGMENTATION/SEGMENTATION/test/images/test_crawling_104.jpg: 640x640 1 caries, 9.1ms
# ...
